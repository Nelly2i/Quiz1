# %%
y = [(2, 4), (7, 8), (1, 5, 9)]

# %%
x = y[1][1]
print(x)
# Out:
# 8

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding='latin-1')

# %%
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
df['Area'].nunique()
# Out:
# 49

# %%
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]

col = ['Age','Nationality','Overall']

# %%
df1 = pd.DataFrame(lst, columns=col, index=[i for i in range(1,4)])
df1.head()
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
df_gpby = df.groupby('Area')['Y2017']
df_gpby.max().sort_values(ascending=False)
# Out:
# Area
# Nigeria                        190873.00
# Ethiopia                       106400.00
# Egypt                           96443.00
# South Africa                    57010.00
# United Republic of Tanzania     54660.00
# Mauritania                      51864.00
# Kenya                           50221.00
# Algeria                         41389.00
# Uganda                          41167.00
# Sudan                           40813.00
# Morocco                         38348.00
# Angola                          29817.00
# Ghana                           29121.00
# Mozambique                      28649.00
# Madagascar                      25571.00
# Cameroon                        24566.00
# Côte d'Ivoire                   24437.00
# Niger                           21602.00
# Burkina Faso                    19193.00
# Mali                            18512.00
# Malawi                          17670.00
# Zambia                          16854.00
# Senegal                         15419.00
# ...

# %%
df.shape
# Out:
# (60943, 12)

# %%
array  = ([[94, 89, 63],

             [93, 92, 48],

             [92, 94, 56]])

# %%
madagascar_2015 = df[(df['Area'] == 'Madagascar') & (df['Y2015'])]
madagascar_2015.head()
# Out:
#        Area Code        Area  Item Code              Item  Element Code  \
# 30715        129  Madagascar       2501        Population           511
# 30717        129  Madagascar       2901       Grand Total           664
# 30718        129  Madagascar       2901       Grand Total           674
# 30719        129  Madagascar       2901       Grand Total           684
# 30720        129  Madagascar       2903  Vegetal Products           664
#
#                                       Element             Unit     Y2014  \
# 30715           Total Population - Both sexes     1000 persons  23590.00
# 30717           Food supply (kcal/capita/day)  kcal/capita/day   1986.00
# 30718  Protein supply quantity (g/capita/day)     g/capita/day     44.45
# 30719      Fat supply quantity (g/capita/day)     g/capita/day     22.18
# 30720           Food supply (kcal/capita/day)  kcal/capita/day   1853.00
#
#           Y2015     Y2016     Y2017     Y2018
# 30715  24234.00  24894.00  25571.00  26262.00
# ...

# %%
madagascar_2015[['Element']=='Protein supply quantity (g/capita/day)'][Y2015]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 madagascar_2015[['Element']=='Protein supply quantity (g/capita/day)'][Y2015]
#
# ...

# %%
df_gpby = df.groupby('Area')['Y2017']
df_gpby.max().sort_values().head(10)
# Out:
# Area
# Ethiopia PDR                0.00
# Sudan (former)              0.00
# Comoros                    16.65
# Seychelles                204.02
# Guinea-Bissau            2233.00
# Botswana                 2341.00
# Sao Tome and Principe    2407.00
# Namibia                  2465.00
# Lesotho                  2475.00
# Cabo Verde               2530.00
# Name: Y2017, dtype: float64

# %%
df.describe(include='all')
# Out:
#            Area Code   Area     Item Code                     Item  \
# count   60943.000000  60943  60943.000000                    60943
# unique           NaN     49           NaN                      119
# top              NaN  Kenya           NaN  Milk - Excluding Butter
# freq             NaN   1560           NaN                     1262
# mean      134.265576    NaN   2687.176706                      NaN
# std        72.605709    NaN    146.055739                      NaN
# min         4.000000    NaN   2501.000000                      NaN
# 25%        74.000000    NaN   2562.000000                      NaN
# 50%       136.000000    NaN   2630.000000                      NaN
# 75%       195.000000    NaN   2775.000000                      NaN
# max       276.000000    NaN   2961.000000                      NaN
#
#         Element Code                   Element         Unit          Y2014  \
# count   60943.000000                     60943        60943   59354.000000
# ...

# %%
df['Y2014'].isnull().sum()
# Out:
# 1589

# %%
df_gpby = df.groupby('Element')['Element']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 df_gpby = df.groupby('Element').df['Element']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1308, in GroupBy.__getattr__(self, attr)
#    1305 if attr in self.obj:
#    1306     return self[attr]
# -> 1308 raise AttributeError(
#    1309     f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1310 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'df'

# %%
df.select_dtypes('int', 'float64', ).corr()
# Out:
#               Area Code  Item Code  Element Code
# Area Code      1.000000  -0.005159     -0.000209
# Item Code     -0.005159   1.000000     -0.024683
# Element Code  -0.000209  -0.024683      1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
my_tuppy = (1,2,5,8)

my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 3
#       1 my_tuppy = (1,2,5,8)
# ----> 3 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment
